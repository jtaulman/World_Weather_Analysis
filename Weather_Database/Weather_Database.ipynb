# %%
import pandas as pd
import numpy as np

# %%
#Random Lat and Lng sets
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs= np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Nearest City
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 769

# %%
import requests
import time
from datetime import datetime

from config2 import challenge_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + challenge_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | minbu
# City not found. Skipping...
# Processing Record 4 of Set 1 | ponta do sol
# City not found. Skipping...
# Processing Record 5 of Set 1 | dukat
# City not found. Skipping...
# Processing Record 6 of Set 1 | albany
# City not found. Skipping...
# Processing Record 7 of Set 1 | castro
# City not found. Skipping...
# Processing Record 8 of Set 1 | mairana
# City not found. Skipping...
# Processing Record 9 of Set 1 | shu
# City not found. Skipping...
# Processing Record 10 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 11 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 12 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 13 of Set 1 | gazanjyk
# City not found. Skipping...
# Processing Record 14 of Set 1 | taltal
# City not found. Skipping...
# Processing Record 15 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 16 of Set 1 | kawalu
# City not found. Skipping...
# Processing Record 17 of Set 1 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 18 of Set 1 | surt
# City not found. Skipping...
# Processing Record 19 of Set 1 | tupi paulista
# City not found. Skipping...
# Processing Record 20 of Set 1 | pisco
# City not found. Skipping...
# Processing Record 21 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 22 of Set 1 | cayenne
# City not found. Skipping...
# Processing Record 23 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 24 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 25 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 26 of Set 1 | meulaboh
# City not found. Skipping...
# Processing Record 27 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 28 of Set 1 | beidao
# City not found. Skipping...
# Processing Record 29 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 30 of Set 1 | sitka
# City not found. Skipping...
# Processing Record 31 of Set 1 | rudsar
# City not found. Skipping...
# Processing Record 32 of Set 1 | lavrentiya
# City not found. Skipping...
# Processing Record 33 of Set 1 | birao
# City not found. Skipping...
# Processing Record 34 of Set 1 | ghanzi
# City not found. Skipping...
# Processing Record 35 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 36 of Set 1 | bani walid
# City not found. Skipping...
# Processing Record 37 of Set 1 | puerto cabezas
# City not found. Skipping...
# Processing Record 38 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 41 of Set 1 | samana
# City not found. Skipping...
# Processing Record 42 of Set 1 | tarragona
# City not found. Skipping...
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | faya
# City not found. Skipping...
# Processing Record 45 of Set 1 | ravar
# City not found. Skipping...
# Processing Record 46 of Set 1 | alexandria
# City not found. Skipping...
# Processing Record 47 of Set 1 | morehead
# City not found. Skipping...
# Processing Record 48 of Set 1 | ahipara
# City not found. Skipping...
# Processing Record 49 of Set 1 | san cristobal
# City not found. Skipping...
# Processing Record 50 of Set 1 | portland
# City not found. Skipping...
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | praia da vitoria
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | hervey bay
# Processing Record 7 of Set 2 | keti bandar
# Processing Record 8 of Set 2 | saint-denis
# Processing Record 9 of Set 2 | pampas
# Processing Record 10 of Set 2 | port moresby
# Processing Record 11 of Set 2 | tymovskoye
# Processing Record 12 of Set 2 | maiduguri
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | anadyr
# Processing Record 16 of Set 2 | lorengau
# Processing Record 17 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 2 | phangnga
# Processing Record 22 of Set 2 | nianzishan
# Processing Record 23 of Set 2 | pangnirtung
# Processing Record 24 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 25 of Set 2 | vila franca do campo
# Processing Record 26 of Set 2 | ostrovnoy
# Processing Record 27 of Set 2 | maningrida
# Processing Record 28 of Set 2 | barra do garcas
# Processing Record 29 of Set 2 | kagoro
# Processing Record 30 of Set 2 | xifeng
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 2 | contamana
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | vostok
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | te anau
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | rio linda
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | fasa
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | port-gentil
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | lovozero
# Processing Record 3 of Set 3 | kavaratti
# Processing Record 4 of Set 3 | vetas
# Processing Record 5 of Set 3 | jumla
# Processing Record 6 of Set 3 | torquay
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | santa rosa
# Processing Record 10 of Set 3 | vanavara
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | uppsala
# Processing Record 14 of Set 3 | sioux lookout
# Processing Record 15 of Set 3 | nizhniy ingash
# Processing Record 16 of Set 3 | bojnurd
# Processing Record 17 of Set 3 | egvekinot
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | mehamn
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | nemuro
# Processing Record 25 of Set 3 | linqiong
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | belmonte
# Processing Record 28 of Set 3 | kapaa
# Processing Record 29 of Set 3 | ketchikan
# Processing Record 30 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 3 | kings mountain
# Processing Record 32 of Set 3 | carutapera
# Processing Record 33 of Set 3 | palora
# Processing Record 34 of Set 3 | watertown
# Processing Record 35 of Set 3 | mwinilunga
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | razole
# Processing Record 38 of Set 3 | healdsburg
# Processing Record 39 of Set 3 | zaozerne
# Processing Record 40 of Set 3 | yellowknife
# Processing Record 41 of Set 3 | tura
# Processing Record 42 of Set 3 | cap-aux-meules
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | dingle
# Processing Record 45 of Set 3 | tara
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | rundu
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | paamiut
# Processing Record 50 of Set 3 | kizema
# Processing Record 1 of Set 4 | liepaja
# Processing Record 2 of Set 4 | nouadhibou
# Processing Record 3 of Set 4 | kanda
# Processing Record 4 of Set 4 | amazar
# Processing Record 5 of Set 4 | magistralnyy
# Processing Record 6 of Set 4 | iqaluit
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | tshikapa
# Processing Record 13 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 4 | tahe
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | svetlyy
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | rio branco
# Processing Record 20 of Set 4 | rio grande
# Processing Record 21 of Set 4 | naze
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | erenhot
# Processing Record 24 of Set 4 | gigmoto
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | victoria
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | thiruvananthapuram
# Processing Record 30 of Set 4 | jalu
# Processing Record 31 of Set 4 | baiyin
# Processing Record 32 of Set 4 | sur
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | skibbereen
# Processing Record 35 of Set 4 | georgiyevka
# Processing Record 36 of Set 4 | atuona
# Processing Record 37 of Set 4 | asau
# Processing Record 38 of Set 4 | san quintin
# Processing Record 39 of Set 4 | ndjole
# Processing Record 40 of Set 4 | opuwo
# Processing Record 41 of Set 4 | saa
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | belozerskoye
# Processing Record 44 of Set 4 | coffs harbour
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | mongo
# Processing Record 47 of Set 4 | namibe
# Processing Record 48 of Set 4 | phichit
# Processing Record 49 of Set 4 | houma
# Processing Record 50 of Set 4 | ratnagiri
# Processing Record 1 of Set 5 | chifeng
# Processing Record 2 of Set 5 | broome
# Processing Record 3 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 5 | lixourion
# Processing Record 5 of Set 5 | cherskiy
# Processing Record 6 of Set 5 | olafsvik
# Processing Record 7 of Set 5 | manono
# Processing Record 8 of Set 5 | ust-nera
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | narrabri
# Processing Record 11 of Set 5 | keningau
# Processing Record 12 of Set 5 | mogadishu
# Processing Record 13 of Set 5 | ati
# Processing Record 14 of Set 5 | sinop
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | moses lake
# Processing Record 17 of Set 5 | kensington
# Processing Record 18 of Set 5 | butaritari
# Processing Record 19 of Set 5 | biak
# Processing Record 20 of Set 5 | dana point
# Processing Record 21 of Set 5 | sisophon
# Processing Record 22 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 5 | port blair
# Processing Record 24 of Set 5 | baherden
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | port hedland
# Processing Record 27 of Set 5 | athabasca
# Processing Record 28 of Set 5 | smidovich
# Processing Record 29 of Set 5 | san jeronimo
# Processing Record 30 of Set 5 | kedarnath
# City not found. Skipping...
# Processing Record 31 of Set 5 | kayan
# Processing Record 32 of Set 5 | marawi
# Processing Record 33 of Set 5 | honningsvag
# Processing Record 34 of Set 5 | korla
# Processing Record 35 of Set 5 | rocha
# Processing Record 36 of Set 5 | burica
# City not found. Skipping...
# Processing Record 37 of Set 5 | perene
# Processing Record 38 of Set 5 | charleston
# Processing Record 39 of Set 5 | fairbanks
# Processing Record 40 of Set 5 | koumac
# Processing Record 41 of Set 5 | ribas do rio pardo
# Processing Record 42 of Set 5 | kulhudhuffushi
# Processing Record 43 of Set 5 | salur
# Processing Record 44 of Set 5 | yulara
# Processing Record 45 of Set 5 | aykhal
# Processing Record 46 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 5 | paralimni
# Processing Record 48 of Set 5 | verkhnyaya toyma
# Processing Record 49 of Set 5 | hithadhoo
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | payakumbuh
# Processing Record 2 of Set 6 | naron
# Processing Record 3 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 6 | hanmer springs
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | ferme-neuve
# Processing Record 7 of Set 6 | pangkalanbuun
# Processing Record 8 of Set 6 | coxim
# Processing Record 9 of Set 6 | redlands
# Processing Record 10 of Set 6 | mayumba
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | la concepcion los banos
# City not found. Skipping...
# Processing Record 13 of Set 6 | college
# Processing Record 14 of Set 6 | margosatubig
# Processing Record 15 of Set 6 | rio cuarto
# Processing Record 16 of Set 6 | dembi dolo
# Processing Record 17 of Set 6 | issenye
# Processing Record 18 of Set 6 | tessaoua
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | humaita
# Processing Record 22 of Set 6 | muzhi
# Processing Record 23 of Set 6 | padang
# Processing Record 24 of Set 6 | pedro juan caballero
# Processing Record 25 of Set 6 | motygino
# Processing Record 26 of Set 6 | chokurdakh
# Processing Record 27 of Set 6 | sabirabad
# Processing Record 28 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 29 of Set 6 | mae hong son
# Processing Record 30 of Set 6 | progreso
# Processing Record 31 of Set 6 | sao felix do xingu
# Processing Record 32 of Set 6 | launceston
# Processing Record 33 of Set 6 | jijiang
# Processing Record 34 of Set 6 | sandviken
# Processing Record 35 of Set 6 | leh
# Processing Record 36 of Set 6 | darnah
# Processing Record 37 of Set 6 | udarnyy
# Processing Record 38 of Set 6 | aksarka
# Processing Record 39 of Set 6 | souillac
# Processing Record 40 of Set 6 | bandarbeyla
# Processing Record 41 of Set 6 | andenes
# Processing Record 42 of Set 6 | amapa
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | roald
# Processing Record 45 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 6 | ucluelet
# Processing Record 47 of Set 6 | merauke
# Processing Record 48 of Set 6 | svidnik
# Processing Record 49 of Set 6 | jeremie
# Processing Record 50 of Set 6 | praia
# Processing Record 1 of Set 7 | grand-santi
# Processing Record 2 of Set 7 | manokwari
# Processing Record 3 of Set 7 | santa marta
# Processing Record 4 of Set 7 | sisimiut
# Processing Record 5 of Set 7 | laredo
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | colares
# Processing Record 8 of Set 7 | salalah
# Processing Record 9 of Set 7 | bethel
# Processing Record 10 of Set 7 | libreville
# Processing Record 11 of Set 7 | south yuba city
# Processing Record 12 of Set 7 | ereymentau
# Processing Record 13 of Set 7 | ilulissat
# Processing Record 14 of Set 7 | beyla
# Processing Record 15 of Set 7 | taoudenni
# Processing Record 16 of Set 7 | nantucket
# Processing Record 17 of Set 7 | longyearbyen
# Processing Record 18 of Set 7 | east london
# Processing Record 19 of Set 7 | rio de janeiro
# Processing Record 20 of Set 7 | wanning
# Processing Record 21 of Set 7 | el carrizo
# Processing Record 22 of Set 7 | krasnoarmeysk
# Processing Record 23 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 7 | komsomolskiy
# Processing Record 25 of Set 7 | bathsheba
# Processing Record 26 of Set 7 | rawah
# Processing Record 27 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 7 | baie-comeau
# Processing Record 29 of Set 7 | dunedin
# Processing Record 30 of Set 7 | araouane
# Processing Record 31 of Set 7 | moron
# Processing Record 32 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 7 | matara
# Processing Record 34 of Set 7 | ilhabela
# Processing Record 35 of Set 7 | bo phloi
# Processing Record 36 of Set 7 | canico
# Processing Record 37 of Set 7 | am timan
# Processing Record 38 of Set 7 | kemijarvi
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | westport
# Processing Record 41 of Set 7 | cidreira
# Processing Record 42 of Set 7 | talaya
# Processing Record 43 of Set 7 | jieshi
# Processing Record 44 of Set 7 | zhangye
# Processing Record 45 of Set 7 | chachapoyas
# Processing Record 46 of Set 7 | sabha
# Processing Record 47 of Set 7 | khokhryaki
# Processing Record 48 of Set 7 | labuhan
# Processing Record 49 of Set 7 | kaseda
# Processing Record 50 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 8 | mawlaik
# Processing Record 2 of Set 8 | banda aceh
# Processing Record 3 of Set 8 | trogir
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | flinders
# Processing Record 6 of Set 8 | rio gallegos
# Processing Record 7 of Set 8 | kutum
# Processing Record 8 of Set 8 | san andres
# Processing Record 9 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 10 of Set 8 | visby
# Processing Record 11 of Set 8 | vinh
# Processing Record 12 of Set 8 | borogontsy
# Processing Record 13 of Set 8 | frontera
# Processing Record 14 of Set 8 | ranong
# Processing Record 15 of Set 8 | goderich
# Processing Record 16 of Set 8 | olovyannaya
# Processing Record 17 of Set 8 | carroll
# Processing Record 18 of Set 8 | ormara
# Processing Record 19 of Set 8 | aquiraz
# Processing Record 20 of Set 8 | yurga
# Processing Record 21 of Set 8 | bafq
# Processing Record 22 of Set 8 | puerto baquerizo moreno
# Processing Record 23 of Set 8 | killybegs
# Processing Record 24 of Set 8 | gazli
# Processing Record 25 of Set 8 | bilibino
# Processing Record 26 of Set 8 | tahta
# Processing Record 27 of Set 8 | upernavik
# Processing Record 28 of Set 8 | guiratinga
# Processing Record 29 of Set 8 | santa luzia
# Processing Record 30 of Set 8 | atar
# Processing Record 31 of Set 8 | nalut
# Processing Record 32 of Set 8 | saldanha
# Processing Record 33 of Set 8 | huangmei
# Processing Record 34 of Set 8 | rupert
# Processing Record 35 of Set 8 | porto walter
# Processing Record 36 of Set 8 | isla vista
# Processing Record 37 of Set 8 | strezhevoy
# Processing Record 38 of Set 8 | lugo
# Processing Record 39 of Set 8 | brookings
# Processing Record 40 of Set 8 | dakar
# Processing Record 41 of Set 8 | dongsheng
# Processing Record 42 of Set 8 | sangar
# Processing Record 43 of Set 8 | elizabeth city
# Processing Record 44 of Set 8 | morondava
# Processing Record 45 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 8 | skjervoy
# Processing Record 48 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 8 | vardo
# Processing Record 50 of Set 8 | krasnozerskoye
# Processing Record 1 of Set 9 | viedma
# Processing Record 2 of Set 9 | polunochnoye
# Processing Record 3 of Set 9 | ontario
# Processing Record 4 of Set 9 | sokoto
# Processing Record 5 of Set 9 | santa cruz de la palma
# Processing Record 6 of Set 9 | chengkung
# City not found. Skipping...
# Processing Record 7 of Set 9 | anloga
# Processing Record 8 of Set 9 | hualmay
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | kirakira
# Processing Record 11 of Set 9 | polyanka
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | alekseyevsk
# Processing Record 14 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 9 | sosnovo-ozerskoye
# Processing Record 16 of Set 9 | isangel
# Processing Record 17 of Set 9 | baghdad
# Processing Record 18 of Set 9 | shingu
# Processing Record 19 of Set 9 | najran
# Processing Record 20 of Set 9 | maniitsoq
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | nouakchott
# Processing Record 23 of Set 9 | port macquarie
# Processing Record 24 of Set 9 | katherine
# Processing Record 25 of Set 9 | grande prairie
# Processing Record 26 of Set 9 | cerrito
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | kumluca
# Processing Record 29 of Set 9 | chinsali
# Processing Record 30 of Set 9 | haines junction
# Processing Record 31 of Set 9 | whitehorse
# Processing Record 32 of Set 9 | severnyy
# Processing Record 33 of Set 9 | thinadhoo
# Processing Record 34 of Set 9 | winslow
# Processing Record 35 of Set 9 | albi
# Processing Record 36 of Set 9 | la gaulette
# City not found. Skipping...
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | ovruch
# Processing Record 39 of Set 9 | puerto madryn
# Processing Record 40 of Set 9 | sovetskiy
# Processing Record 41 of Set 9 | arvika
# Processing Record 42 of Set 9 | belaya gora
# Processing Record 43 of Set 9 | palanga
# Processing Record 44 of Set 9 | alice springs
# Processing Record 45 of Set 9 | kalmunai
# Processing Record 46 of Set 9 | quelimane
# Processing Record 47 of Set 9 | kieta
# Processing Record 48 of Set 9 | tokur
# Processing Record 49 of Set 9 | noumea
# Processing Record 50 of Set 9 | kindu
# Processing Record 1 of Set 10 | palmer
# Processing Record 2 of Set 10 | hanamaki
# Processing Record 3 of Set 10 | khotynets
# Processing Record 4 of Set 10 | garowe
# Processing Record 5 of Set 10 | alibag
# Processing Record 6 of Set 10 | sao pedro do sul
# Processing Record 7 of Set 10 | hanzhong
# Processing Record 8 of Set 10 | pangody
# Processing Record 9 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 10 | bayangol
# Processing Record 11 of Set 10 | paita
# Processing Record 12 of Set 10 | kiruna
# Processing Record 13 of Set 10 | nabire
# Processing Record 14 of Set 10 | fomboni
# Processing Record 15 of Set 10 | germantown
# Processing Record 16 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 10 | show low
# Processing Record 18 of Set 10 | novichikha
# Processing Record 19 of Set 10 | rabo de peixe
# Processing Record 20 of Set 10 | turukhansk
# Processing Record 21 of Set 10 | vieques
# Processing Record 22 of Set 10 | newberry
# Processing Record 23 of Set 10 | sorrento
# Processing Record 24 of Set 10 | zeerust
# Processing Record 25 of Set 10 | coahuayana
# Processing Record 26 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | tashtagol
# Processing Record 29 of Set 10 | laguna
# Processing Record 30 of Set 10 | baruun-urt
# Processing Record 31 of Set 10 | sambava
# Processing Record 32 of Set 10 | yuzhno-kurilsk
# Processing Record 33 of Set 10 | kununurra
# Processing Record 34 of Set 10 | emerald
# Processing Record 35 of Set 10 | coquimbo
# Processing Record 36 of Set 10 | qasigiannguit
# Processing Record 37 of Set 10 | turayf
# Processing Record 38 of Set 10 | gondanglegi
# Processing Record 39 of Set 10 | brajrajnagar
# City not found. Skipping...
# Processing Record 40 of Set 10 | los banos
# Processing Record 41 of Set 10 | vanimo
# Processing Record 42 of Set 10 | komyshany
# Processing Record 43 of Set 10 | nieuw amsterdam
# Processing Record 44 of Set 10 | plouzane
# Processing Record 45 of Set 10 | gotsu
# Processing Record 46 of Set 10 | calbayog
# Processing Record 47 of Set 10 | borujan
# City not found. Skipping...
# Processing Record 48 of Set 10 | mackay
# Processing Record 49 of Set 10 | puerto colombia
# Processing Record 50 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 1 of Set 11 | sinnamary
# Processing Record 2 of Set 11 | margate
# Processing Record 3 of Set 11 | jerez
# Processing Record 4 of Set 11 | disna
# Processing Record 5 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 6 of Set 11 | ust-kan
# Processing Record 7 of Set 11 | petropavlovka
# Processing Record 8 of Set 11 | hofn
# Processing Record 9 of Set 11 | lebowakgomo
# Processing Record 10 of Set 11 | novopokrovka
# Processing Record 11 of Set 11 | teseney
# Processing Record 12 of Set 11 | jiwani
# Processing Record 13 of Set 11 | erzin
# Processing Record 14 of Set 11 | winneba
# Processing Record 15 of Set 11 | mondeville
# Processing Record 16 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 11 | kanniyakumari
# Processing Record 18 of Set 11 | las vegas
# Processing Record 19 of Set 11 | exeter
# Processing Record 20 of Set 11 | high rock
# Processing Record 21 of Set 11 | bantry
# Processing Record 22 of Set 11 | plettenberg bay
# Processing Record 23 of Set 11 | zhigansk
# Processing Record 24 of Set 11 | jackson
# Processing Record 25 of Set 11 | diu
# Processing Record 26 of Set 11 | esso
# Processing Record 27 of Set 11 | lompoc
# Processing Record 28 of Set 11 | were ilu
# Processing Record 29 of Set 11 | broken hill
# Processing Record 30 of Set 11 | presidencia roque saenz pena
# Processing Record 31 of Set 11 | ola
# Processing Record 32 of Set 11 | takoradi
# Processing Record 33 of Set 11 | mersing
# Processing Record 34 of Set 11 | asfi
# Processing Record 35 of Set 11 | ako
# Processing Record 36 of Set 11 | kavieng
# Processing Record 37 of Set 11 | ampanihy
# Processing Record 38 of Set 11 | chapais
# Processing Record 39 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 11 | colac
# Processing Record 41 of Set 11 | byron bay
# Processing Record 42 of Set 11 | saint-pierre
# Processing Record 43 of Set 11 | ous
# Processing Record 44 of Set 11 | severnoye
# Processing Record 45 of Set 11 | tautira
# Processing Record 46 of Set 11 | namie
# Processing Record 47 of Set 11 | la tuque
# Processing Record 48 of Set 11 | finschhafen
# Processing Record 49 of Set 11 | golspie
# Processing Record 50 of Set 11 | zhezkazgan
# Processing Record 1 of Set 12 | lampazos de naranjo
# Processing Record 2 of Set 12 | chimbote
# Processing Record 3 of Set 12 | loreto
# Processing Record 4 of Set 12 | basco
# Processing Record 5 of Set 12 | bosobolo
# Processing Record 6 of Set 12 | fortuna
# Processing Record 7 of Set 12 | aklavik
# Processing Record 8 of Set 12 | suwannaphum
# Processing Record 9 of Set 12 | lahaina
# Processing Record 10 of Set 12 | vanino
# Processing Record 11 of Set 12 | corner brook
# Processing Record 12 of Set 12 | martapura
# Processing Record 13 of Set 12 | kabelvag
# Processing Record 14 of Set 12 | parasia
# Processing Record 15 of Set 12 | klaksvik
# Processing Record 16 of Set 12 | shelopugino
# Processing Record 17 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 12 | karasuk
# Processing Record 19 of Set 12 | yazoo city
# Processing Record 20 of Set 12 | maraa
# Processing Record 21 of Set 12 | bagdarin
# Processing Record 22 of Set 12 | kahului
# Processing Record 23 of Set 12 | wichita falls
# Processing Record 24 of Set 12 | inhambane
# Processing Record 25 of Set 12 | vestmannaeyjar
# Processing Record 26 of Set 12 | zyryanka
# Processing Record 27 of Set 12 | los llanos de aridane
# Processing Record 28 of Set 12 | alamosa
# Processing Record 29 of Set 12 | nuuk
# Processing Record 30 of Set 12 | abapo
# Processing Record 31 of Set 12 | macheng
# Processing Record 32 of Set 12 | dublin
# Processing Record 33 of Set 12 | aborlan
# Processing Record 34 of Set 12 | sakakah
# Processing Record 35 of Set 12 | de aar
# Processing Record 36 of Set 12 | tatarsk
# Processing Record 37 of Set 12 | nanzhang
# Processing Record 38 of Set 12 | ranchuelo
# Processing Record 39 of Set 12 | doha
# Processing Record 40 of Set 12 | nishihara
# Processing Record 41 of Set 12 | carinhanha
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | maldonado
# Processing Record 44 of Set 12 | beloha
# Processing Record 45 of Set 12 | pasighat
# Processing Record 46 of Set 12 | yar-sale
# Processing Record 47 of Set 12 | letlhakeng
# Processing Record 48 of Set 12 | urubicha
# Processing Record 49 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 12 | kasama
# Processing Record 1 of Set 13 | never
# Processing Record 2 of Set 13 | portobelo
# Processing Record 3 of Set 13 | bubaque
# Processing Record 4 of Set 13 | abong mbang
# Processing Record 5 of Set 13 | sechura
# Processing Record 6 of Set 13 | acarau
# Processing Record 7 of Set 13 | trelew
# Processing Record 8 of Set 13 | lukovetskiy
# Processing Record 9 of Set 13 | benjamin aceval
# Processing Record 10 of Set 13 | ukiah
# Processing Record 11 of Set 13 | kaeo
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | abay
# Processing Record 14 of Set 13 | caibarien
# Processing Record 15 of Set 13 | hami
# Processing Record 16 of Set 13 | quatre cocos
# Processing Record 17 of Set 13 | ryotsu
# Processing Record 18 of Set 13 | hirado
# Processing Record 19 of Set 13 | camara de lobos
# Processing Record 20 of Set 13 | cururupu
# Processing Record 21 of Set 13 | zlitan
# Processing Record 22 of Set 13 | lubango
# Processing Record 23 of Set 13 | saint-leu
# Processing Record 24 of Set 13 | otradnoye
# Processing Record 25 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 13 | santiago
# Processing Record 27 of Set 13 | ardesen
# Processing Record 28 of Set 13 | fare
# Processing Record 29 of Set 13 | port-cartier
# Processing Record 30 of Set 13 | vao
# Processing Record 31 of Set 13 | havre-saint-pierre
# Processing Record 32 of Set 13 | kyra
# Processing Record 33 of Set 13 | provost
# Processing Record 34 of Set 13 | pinawa
# Processing Record 35 of Set 13 | zhetybay
# City not found. Skipping...
# Processing Record 36 of Set 13 | binzhou
# Processing Record 37 of Set 13 | wabana
# Processing Record 38 of Set 13 | fort nelson
# Processing Record 39 of Set 13 | sorland
# Processing Record 40 of Set 13 | lobito
# Processing Record 41 of Set 13 | poum
# Processing Record 42 of Set 13 | ust-tsilma
# Processing Record 43 of Set 13 | luganville
# Processing Record 44 of Set 13 | beisfjord
# Processing Record 45 of Set 13 | yashkul
# Processing Record 46 of Set 13 | nikki
# Processing Record 47 of Set 13 | guaruja
# Processing Record 48 of Set 13 | midland
# Processing Record 49 of Set 13 | avera
# Processing Record 50 of Set 13 | chico
# Processing Record 1 of Set 14 | prince rupert
# Processing Record 2 of Set 14 | lazaro cardenas
# Processing Record 3 of Set 14 | gambela
# Processing Record 4 of Set 14 | banos
# Processing Record 5 of Set 14 | tateyama
# Processing Record 6 of Set 14 | shimoda
# Processing Record 7 of Set 14 | olinda
# Processing Record 8 of Set 14 | tual
# Processing Record 9 of Set 14 | palatka
# Processing Record 10 of Set 14 | praya
# Processing Record 11 of Set 14 | kerrville
# Processing Record 12 of Set 14 | petlawad
# Processing Record 13 of Set 14 | czluchow
# Processing Record 14 of Set 14 | kampene
# Processing Record 15 of Set 14 | pinheiro machado
# Processing Record 16 of Set 14 | gornoye loo
# Processing Record 17 of Set 14 | hobyo
# Processing Record 18 of Set 14 | qui nhon
# Processing Record 19 of Set 14 | gamba
# Processing Record 20 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 14 | katsuura
# Processing Record 22 of Set 14 | zinder
# Processing Record 23 of Set 14 | deputatskiy
# Processing Record 24 of Set 14 | charlestown
# Processing Record 25 of Set 14 | cockburn town
# Processing Record 26 of Set 14 | ambilobe
# Processing Record 27 of Set 14 | manado
# Processing Record 28 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 14 | blackpool
# Processing Record 30 of Set 14 | bandiagara
# Processing Record 31 of Set 14 | magdagachi
# Processing Record 32 of Set 14 | helong
# Processing Record 33 of Set 14 | blackwater
# Processing Record 34 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 35 of Set 14 | milkovo
# Processing Record 36 of Set 14 | samarai
# Processing Record 37 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 14 | waipawa
# Processing Record 39 of Set 14 | shieli
# Processing Record 40 of Set 14 | iralaya
# Processing Record 41 of Set 14 | tabou
# Processing Record 42 of Set 14 | grootfontein
# Processing Record 43 of Set 14 | darab
# Processing Record 44 of Set 14 | wattegama
# Processing Record 45 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 46 of Set 14 | gravdal
# Processing Record 47 of Set 14 | san pedro
# Processing Record 48 of Set 14 | the valley
# Processing Record 49 of Set 14 | pilar
# Processing Record 50 of Set 14 | miguel calmon
# Processing Record 1 of Set 15 | huilong
# Processing Record 2 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 15 | camargo
# Processing Record 4 of Set 15 | kysyl-syr
# Processing Record 5 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 15 | schruns
# Processing Record 7 of Set 15 | shizukuishi
# Processing Record 8 of Set 15 | pacific grove
# Processing Record 9 of Set 15 | kupang
# Processing Record 10 of Set 15 | dali
# Processing Record 11 of Set 15 | hay river
# Processing Record 12 of Set 15 | almaznyy
# Processing Record 13 of Set 15 | marrakesh
# Processing Record 14 of Set 15 | flin flon
# Processing Record 15 of Set 15 | ust-ilimsk
# Processing Record 16 of Set 15 | la crosse
# Processing Record 17 of Set 15 | lufilufi
# Processing Record 18 of Set 15 | sarvar
# Processing Record 19 of Set 15 | payo
# Processing Record 20 of Set 15 | miranda
# Processing Record 21 of Set 15 | naberera
# Processing Record 22 of Set 15 | karatuzskoye
# Processing Record 23 of Set 15 | esperance
# Processing Record 24 of Set 15 | jiblah
# Processing Record 25 of Set 15 | okha
# Processing Record 26 of Set 15 | srednekolymsk
# Processing Record 27 of Set 15 | raudeberg
# Processing Record 28 of Set 15 | rockland
# Processing Record 29 of Set 15 | kuryk
# Processing Record 30 of Set 15 | bonthe
# Processing Record 31 of Set 15 | malatya
# Processing Record 32 of Set 15 | manjacaze
# Processing Record 33 of Set 15 | ostuacan
# Processing Record 34 of Set 15 | sakaiminato
# Processing Record 35 of Set 15 | constitucion
# Processing Record 36 of Set 15 | xining
# Processing Record 37 of Set 15 | kunya
# Processing Record 38 of Set 15 | warrensburg
# Processing Record 39 of Set 15 | grand gaube
# Processing Record 40 of Set 15 | natal
# Processing Record 41 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 15 | luderitz
# Processing Record 43 of Set 15 | jinchang
# Processing Record 44 of Set 15 | tabas
# Processing Record 45 of Set 15 | nhulunbuy
# Processing Record 46 of Set 15 | devils lake
# Processing Record 47 of Set 15 | soverato
# Processing Record 48 of Set 15 | mindelo
# Processing Record 49 of Set 15 | madridejos
# Processing Record 50 of Set 15 | moree
# Processing Record 1 of Set 16 | puqi
# Processing Record 2 of Set 16 | belokurikha
# Processing Record 3 of Set 16 | edd
# Processing Record 4 of Set 16 | santa cruz
# Processing Record 5 of Set 16 | grindavik
# Processing Record 6 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 16 | atambua
# Processing Record 8 of Set 16 | dwarka
# Processing Record 9 of Set 16 | victoria point
# Processing Record 10 of Set 16 | ipixuna
# Processing Record 11 of Set 16 | saint-francois
# Processing Record 12 of Set 16 | moose factory
# Processing Record 13 of Set 16 | palana
# Processing Record 14 of Set 16 | eureka
# Processing Record 15 of Set 16 | aranos
# Processing Record 16 of Set 16 | quang ngai
# Processing Record 17 of Set 16 | williston
# Processing Record 18 of Set 16 | elat
# Processing Record 19 of Set 16 | manassas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 667

# %%
#Create a new DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0   Bambous Virieux      MU -20.3428   57.7575     80.85        83
# 1  Praia Da Vitoria      PT  38.7333  -27.0667     64.65        68
# 2      Saint George      US  37.1041 -113.5841     45.36        40
# 3         Cape Town      ZA -33.9258   18.4232     80.11        55
# 4        Hervey Bay      AU -25.2986  152.8535     66.31        78
# 5       Keti Bandar      PK  24.1447   67.4497     71.71        76
# 6       Saint-Denis      FR  48.9167    2.3333     51.51        55
# 7            Pampas      PE -12.4000  -74.9000     57.67        67
# 8      Port Moresby      PG  -9.4431  147.1797     76.42        88
# 9        Tymovskoye      RU  50.8456  142.6550      8.01        96
#
#    Cloudiness  Wind Speed Current Description
# 0          75       10.36          light rain
# 1          20       11.30          few clouds
# 2           0        0.00           clear sky
# 3           0       18.41           clear sky
# 4          63       17.31       broken clouds
# 5           0       10.00           clear sky
# 6           0       11.50           clear sky
# 7          90        6.76     overcast clouds
# 8          20        3.44          few clouds
# 9         100        4.41          light snow

# %%
#Export to CSV
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
